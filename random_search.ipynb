# %%
from util import get_spiral, get_clouds
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import keras
# Out:
# C:\Users\Denis\AppData\Local\conda\conda\envs\tensorflow_env_gpu\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def random_search():
    # get the data and split into train/test
    X, Y = get_spiral()
    # X, Y = get_clouds()
    X, Y = shuffle(X, Y)
    Ntrain = int(0.7*len(X))
    Xtrain, Ytrain = X[:Ntrain], Y[:Ntrain]
    Xtest, Ytest = X[Ntrain:], Y[Ntrain:]

    # starting hyperparameters
    M = 20
    nHidden = 2
    log_lr = -4
    log_l2 = -2 # since we always want it to be positive
    max_tries = 30

    # loop through all possible hyperparameter settings
    best_validation_rate = 0
    best_hls = None
    best_lr = None
    best_l2 = None
    for _ in range(max_tries):
        model = keras.models.Sequential()
        model.add(keras.layers.Dense(units=M, input_dim=Xtrain.shape[1], activation='relu', 
                                             kernel_regularizer=keras.regularizers.l2(10**log_l2)))
        model.add(keras.layers.Dense(1, activation='sigmoid'))
        adam = keras.optimizers.Adam(lr=10**log_lr)
        model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
        hist = model.fit(Xtrain, Ytrain, epochs=3000, batch_size=300, verbose=0, validation_data=(Xtest, Ytest))
        validation_accuracy = hist.history['val_acc'][-1]
        train_accuracy = hist.history['acc'][-1]
        print(
            "validation_accuracy: %.3f, train_accuracy: %.3f, settings: %s, %s, %s" %
            (validation_accuracy, train_accuracy, [M]*nHidden, log_lr, log_l2)
        )
        if validation_accuracy > best_validation_rate:
            best_validation_rate = validation_accuracy
            best_M = M
            best_nHidden = nHidden
            best_lr = log_lr
            best_l2 = log_l2

        # select new hyperparams
        nHidden = best_nHidden + np.random.randint(-1, 2) # -1, 0, or 1
        nHidden = max(1, nHidden)
        M = best_M + np.random.randint(-1, 2)*10
        M = max(10, M)
        log_lr = best_lr + np.random.randint(-1, 2)
        log_l2 = best_l2 + np.random.randint(-1, 2)
        print("Best validation_accuracy:", best_validation_rate)
        print("Best settings:")
        print("best_M:", best_M)
        print("best_nHidden:", best_nHidden)
        print("learning_rate:", best_lr)
        print("l2:", best_l2)

# %%
random_search()
# Out:
# validation_accuracy: 0.650, train_accuracy: 0.717, settings: [20, 20], -4, -2
# Best validation_accuracy: 0.6499999761581421
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.506, train_accuracy: 0.524, settings: [30, 30, 30], -5, -2
# Best validation_accuracy: 0.6499999761581421
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.628, train_accuracy: 0.612, settings: [20, 20], -5, -3
# Best validation_accuracy: 0.6499999761581421
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.456, train_accuracy: 0.545, settings: [20, 20], -5, -3
# Best validation_accuracy: 0.6499999761581421
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.533, train_accuracy: 0.517, settings: [10], -5, -2
# Best validation_accuracy: 0.6499999761581421
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.533, train_accuracy: 0.543, settings: [20, 20], -5, -3
# Best validation_accuracy: 0.6499999761581421
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.672, train_accuracy: 0.707, settings: [20, 20], -4, -2
# Best validation_accuracy: 0.6722221970558167
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.611, train_accuracy: 0.700, settings: [10], -4, -2
# Best validation_accuracy: 0.6722221970558167
# Best settings:
# best_M: 20
# best_nHidden: 2
# learning_rate: -4
# l2: -2
# validation_accuracy: 0.683, train_accuracy: 0.702, settings: [20], -4, -1
# Best validation_accuracy: 0.6833333373069763
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -4
# l2: -1
# validation_accuracy: 0.744, train_accuracy: 0.812, settings: [10], -3, -2
# Best validation_accuracy: 0.7444444298744202
# Best settings:
# best_M: 10
# best_nHidden: 1
# learning_rate: -3
# l2: -2
# validation_accuracy: 0.756, train_accuracy: 0.807, settings: [10], -3, -1
# Best validation_accuracy: 0.7555555701255798
# Best settings:
# best_M: 10
# best_nHidden: 1
# learning_rate: -3
# l2: -1
# validation_accuracy: 0.728, train_accuracy: 0.774, settings: [20, 20], -4, -1
# Best validation_accuracy: 0.7555555701255798
# Best settings:
# best_M: 10
# best_nHidden: 1
# learning_rate: -3
# l2: -1
# validation_accuracy: 0.839, train_accuracy: 0.883, settings: [10], -2, 0
# Best validation_accuracy: 0.8388888835906982
# Best settings:
# best_M: 10
# best_nHidden: 1
# learning_rate: -2
# l2: 0
# validation_accuracy: 0.861, train_accuracy: 0.893, settings: [20], -3, -1
# Best validation_accuracy: 0.8611111044883728
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -1
# validation_accuracy: 0.806, train_accuracy: 0.862, settings: [20], -3, -1
# Best validation_accuracy: 0.8611111044883728
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -1
# validation_accuracy: 0.539, train_accuracy: 0.571, settings: [10], -4, 0
# Best validation_accuracy: 0.8611111044883728
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -1
# validation_accuracy: 0.683, train_accuracy: 0.717, settings: [10], -3, 0
# Best validation_accuracy: 0.8611111044883728
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -1
# validation_accuracy: 0.917, train_accuracy: 0.945, settings: [20], -3, -2
# Best validation_accuracy: 0.9166666865348816
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -2
# validation_accuracy: 0.850, train_accuracy: 0.857, settings: [10], -2, -1
# Best validation_accuracy: 0.9166666865348816
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -2
# validation_accuracy: 0.789, train_accuracy: 0.817, settings: [10], -3, -1
# Best validation_accuracy: 0.9166666865348816
# Best settings:
# best_M: 20
# best_nHidden: 1
# learning_rate: -3
# l2: -2
# validation_accuracy: 0.967, train_accuracy: 0.986, settings: [30], -2, -3
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.900, train_accuracy: 0.929, settings: [30, 30], -3, -2
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.817, train_accuracy: 0.871, settings: [20, 20], -1, -2
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.933, train_accuracy: 0.971, settings: [20], -1, -3
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.950, train_accuracy: 0.960, settings: [20, 20], -2, -3
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.961, train_accuracy: 0.990, settings: [40], -2, -3
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.939, train_accuracy: 0.950, settings: [30], -3, -2
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.950, train_accuracy: 0.964, settings: [30], -3, -3
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.956, train_accuracy: 0.981, settings: [20], -1, -4
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
# validation_accuracy: 0.961, train_accuracy: 0.983, settings: [40], -2, -3
# Best validation_accuracy: 0.9666666388511658
# Best settings:
# best_M: 30
# best_nHidden: 1
# learning_rate: -2
# l2: -3
